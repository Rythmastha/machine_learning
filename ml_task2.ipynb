# %% [markdown]
# # MACHINE LEARNING TASK2 (PART1)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\Vandana Jha\\Downloads\\StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.describe().transpose()
# Out:
#                 count    mean        std   min    25%   50%   75%    max
# math score     1000.0  66.089  15.163080   0.0  57.00  66.0  77.0  100.0
# reading score  1000.0  69.169  14.600192  17.0  59.00  70.0  79.0  100.0
# writing score  1000.0  68.054  15.195657  10.0  57.75  69.0  79.0  100.0

# %% [markdown]
# # QUESTION1

# %%
#question1
#1. Find the average score group wise for males and females separately.

# %%
df.sort_values(['gender','race/ethnicity'])
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 14   female        group A             master's degree      standard
# 46   female        group A          associate's degree      standard
# 72   female        group A          associate's degree  free/reduced
# 88   female        group A                some college      standard
# 129  female        group A           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 928    male        group E          associate's degree  free/reduced
# 950    male        group E                 high school      standard
# 955    male        group E          associate's degree      standard
# 987    male        group E            some high school      standard
# 990    male        group E                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.groupby(['gender','race/ethnicity'])[['math score','reading score','writing score']].mean()
# Out:
#                        math score  reading score  writing score
# gender race/ethnicity
# female group A          58.527778      69.000000      67.861111
#        group B          61.403846      71.076923      70.048077
#        group C          62.033333      71.944444      71.777778
#        group D          65.248062      74.046512      75.023256
#        group E          70.811594      75.840580      75.536232
# male   group A          63.735849      61.735849      59.150943
#        group B          65.930233      62.848837      60.220930
#        group C          67.611511      65.424460      62.712230
#        group D          69.413534      66.135338      65.413534
#        group E          76.746479      70.295775      67.394366

# %% [markdown]
# # QUESTION2

# %%
#question2
#2. Find the % of males scoring above 80 in math and 85 in reading group wise under [parental level of education as bachelor degree

# %%
male_df=df[(df['gender']=='male') & (df['parental level of education']=="bachelor's degree")]
male_df
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 24    male        group D           bachelor's degree  free/reduced
# 60    male        group E           bachelor's degree  free/reduced
# 77    male        group A           bachelor's degree      standard
# 101   male        group D           bachelor's degree      standard
# 134   male        group D           bachelor's degree  free/reduced
# 135   male        group C           bachelor's degree      standard
# 151   male        group A           bachelor's degree      standard
# 153   male        group D           bachelor's degree      standard
# 206   male        group E           bachelor's degree      standard
# 234   male        group C           bachelor's degree      standard
# 236   male        group D           bachelor's degree  free/reduced
# 270   male        group C           bachelor's degree      standard
# 275   male        group C           bachelor's degree      standard
# ...

# %%
y=len(male_df[(male_df['math score']>80) & (male_df['reading score'] > 85)])
y
# Out:
# 5

# %%
x=len(male_df[(male_df['parental level of education']=="bachelor's degree")])
x
# Out:
# 55

# %%
percentage=100*y/x
percentage
# Out:
# 9.090909090909092

# %% [markdown]
# # QUESTION3

# %%
#question3
#3. Find the count of males under group E that are either having parental level of education 
#as high school or under bachelor degree program

# %%
df_new=df[(df['gender']=='male') & (df['race/ethnicity']=="group E")]
df_count=df_new[(df_new['parental level of education']=="bachelor's degree") | (df_new['parental level of education']=='high school')]
df_count
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 60    male        group E           bachelor's degree  free/reduced
# 137   male        group E                 high school      standard
# 186   male        group E                 high school      standard
# 197   male        group E                 high school  free/reduced
# 206   male        group E           bachelor's degree      standard
# 207   male        group E                 high school      standard
# 214   male        group E                 high school      standard
# 415   male        group E                 high school      standard
# 419   male        group E                 high school  free/reduced
# 476   male        group E           bachelor's degree      standard
# 538   male        group E           bachelor's degree      standard
# 592   male        group E           bachelor's degree      standard
# 757   male        group E           bachelor's degree  free/reduced
# ...

# %%
count=len(df_count.axes[0])
count
# Out:
# 18

# %% [markdown]
# # QUESTION 4

# %%
#question 4 
#4. Find the maximum marks for math, reading and writing for each group and plot them

# %%
df2=df.groupby(['race/ethnicity'])[['math score','reading score','writing score']].max()
df2
# Out:
#                 math score  reading score  writing score
# race/ethnicity
# group A                100            100             97
# group B                 97             97             96
# group C                 98            100            100
# group D                100            100            100
# group E                100            100            100

# %%
sns.scatterplot(x='race/ethnicity',y='math score',s=500,data=df2)
plt.figure(figsize=(15,5))

# %%
sns.scatterplot(x='race/ethnicity',y='reading score',s=500,data=df2)
plt.figure(figsize=(15,5))

# %% [markdown]
# sns.scatterplot(x='race/ethnicity',y='writing score',s=500,data=df2)
# plt.figure(figsize=(15,5))

# %% [markdown]
# # QUESTION 5

# %%
#question 5
#5. Plot the count of students based on their gender and whether they have prepared for the test or not

# %%
sns.countplot(data=df,x='gender',hue='test preparation course')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# # QUESTION 6

# %%
#question6
#6. Plot the scores in all three subjects based on their gender

# %%
fig,axes=plt.subplots(nrows=1,ncols=3)
sns.scatterplot(ax=axes[0],data=df,x='gender',y='reading score')
sns.scatterplot(ax=axes[1],data=df,x='gender',y='math score')
sns.scatterplot(ax=axes[2],data=df,x='gender',y='writing score')
plt.tight_layout()

# %%
#showing using barplot
fig,axes=plt.subplots(nrows=1,ncols=3)
sns.barplot(ax=axes[0],data=df,x='gender',y='reading score')
sns.barplot(ax=axes[1],data=df,x='gender',y='math score')
sns.barplot(ax=axes[2],data=df,x='gender',y='writing score')
plt.tight_layout()

# %%
#plotting them together in a single grpah
df.plot.bar(y=['math score','writing score','reading score'],x="gender",figsize=(5,5))
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
df.plot(y=['math score','writing score','reading score'],x="gender",kind="hist",figsize=(5,5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # QUESTION 7

# %%
#question7
#7. Plot the relations between various columns based on the correlation coefficient

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # QUESTION 8

# %%
#question 8 
#8. Plot the scores of each student group wise and parental level of education

# %%
sns.countplot(x='race/ethnicity',data=df,hue='parental level of education')
plt.figure(figsize=(15,5))

# %% [markdown]
# # QUESTION 9

# %%
#question 9
#9. Plot the relation between marks and preparation that will help understand them properly

# %%
fig,axes=plt.subplots(nrows=1,ncols=3)
sns.barplot(ax=axes[0],data=df,x='test preparation course',y='reading score')
sns.barplot(ax=axes[1],data=df,x='test preparation course',y='math score')
sns.barplot(ax=axes[2],data=df,x='test preparation course',y='writing score')
plt.tight_layout()

# %%
fig,axes=plt.subplots(nrows=1,ncols=3)
sns.scatterplot(ax=axes[0],data=df,x='math score',y='test preparation course')
sns.scatterplot(ax=axes[1],data=df,x='reading score',y='test preparation course')
sns.scatterplot(ax=axes[2],data=df,x='writing score',y='test preparation course')
plt.tight_layout()

# %% [markdown]
# # QUESTION 10

# %%
#question 10
#10. Using any kind of plot, find whether the data is left skewed or right skewed based on scores of each subject.

# %%
fig,axes=plt.subplots(nrows=1,ncols=3)
sns.kdeplot(ax=axes[0],data=df,x='math score')
sns.kdeplot(ax=axes[1],data=df,x='writing score')
sns.kdeplot(ax=axes[2],data=df,x='reading score')
plt.tight_layout()

# %% [markdown]
# AFTER NOTICING THE GRAPHS,IT APPEARS THAT THE DATA IS RIGHT SKEWED

# %% [markdown]
# # BONUS

# %%
#BONUS
#Perform one hot encoding to prepare the dataset for ML models

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\Vandana Jha\\Downloads\\StudentsPerformance.csv")

# %%
print(df['gender'].unique())
print(df['race/ethnicity'].unique())
print(df['test preparation course'].unique())
print(df['parental level of education'].unique())
# Out:
# ['female' 'male']
# ['group B' 'group C' 'group A' 'group D' 'group E']
# ['none' 'completed']
# ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']

# %%
df['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
one_hot_encode_df=pd.get_dummies(df,columns=['gender'])
one_hot_encode_df.head()
# Out:
#   race/ethnicity parental level of education         lunch  \
# 0        group B           bachelor's degree      standard
# 1        group C                some college      standard
# 2        group B             master's degree      standard
# 3        group A          associate's degree  free/reduced
# 4        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    gender_female  gender_male
# 0              1            0
# 1              1            0
# 2              1            0
# 3              0            1
# 4              0            1
