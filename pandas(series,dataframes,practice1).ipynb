# %%
import numpy as np
import pandas as pd

# %%
#series
my_index=['USA','mexico','canada']

# %%
my_data=[1776,1867,1821]

# %%
myser=pd.Series(data=my_data)

# %%
myser
# Out:
# 0    1776
# 1    1867
# 2    1821
# dtype: int64

# %%
myser=pd.Series(data=my_data,index=my_index)

# %%
myser
# Out:
# USA       1776
# mexico    1867
# canada    1821
# dtype: int64

# %%
myser['USA']
# Out:
# 1776

# %%
myser[0]
# Out:
# 1776

# %%
#can directly call data and index by the variable name
myser=pd.Series(my_data,my_index)
myser
# Out:
# USA       1776
# mexico    1867
# canada    1821
# dtype: int64

# %%
#another way of creating using dictionaries
ages={'astha':18,'diya':15,'ayush':16}
pd.Series(ages)
# Out:
# astha    18
# diya     15
# ayush    16
# dtype: int64

# %%
#coding exercise
#taking out bobs_expenses
expenses=pd.Series({'andrew':200,'bob':150,'claire':450})
bobs_expenses=expenses[1]
bobs_expenses
# Out:
# 150

# %%
# Imaginary Sales Data for 1st and 2nd Quarters for Global Company
q1 = {'Japan': 80, 'China': 450, 'India': 200, 'USA': 250}
q2 = {'Brazil': 100,'China': 500, 'India': 210,'USA': 260}

# %%
# Convert into Pandas Series
sales_Q1 = pd.Series(q1)
sales_Q2 = pd.Series(q2)

# %%
sales_Q1
# Out:
# Japan     80
# China    450
# India    200
# USA      250
# dtype: int64

# %%
sales_Q1[0]
# Out:
# 80

# %%
sales_Q1.keys()
# Out:
# Index(['Japan', 'China', 'India', 'USA'], dtype='object')

# %%
#operation
sales_Q1*2
# Out:
# Japan    160
# China    900
# India    400
# USA      500
# dtype: int64

# %%
sales_Q1+sales_Q2
#Nan in brazil and japan because its not present in both the series rather just one of them
# Out:
# Brazil      NaN
# China     950.0
# India     410.0
# Japan       NaN
# USA       510.0
# dtype: float64

# %%
#filling the nan with any random value
sales_Q1.add(sales_Q2,fill_value=0)
#now brazil and japan contains the value of one of their sales and the other sale 2 is considered to be zero
# Out:
# Brazil    100.0
# China     950.0
# India     410.0
# Japan      80.0
# USA       510.0
# dtype: float64

# %%
#dataframes

# %%
# Make sure the seed is in the same cell as the random call
np.random.seed(101)
mydata = np.random.randint(0,101,(4,3))

# %%
mydata
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
myindex=['CA','NY','AZ','TX']

# %%
mycolumns=['jan','feb','march']

# %%
df=pd.DataFrame(mydata,myindex)
df
# Out:
#      0   1   2
# CA  95  11  81
# NY  70  63  87
# AZ  75   9  77
# TX  40   4  63

# %%
df=pd.DataFrame(mydata,myindex,mycolumns)
df
# Out:
#     jan  feb  march
# CA   95   11     81
# NY   70   63     87
# AZ   75    9     77
# TX   40    4     63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, CA to TX
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   jan     4 non-null      int32
#  1   feb     4 non-null      int32
#  2   march   4 non-null      int32
# dtypes: int32(3)
# memory usage: 80.0+ bytes

# %%
#reading a .csv file for dataframe(csv=comma separated varibales)

# %%
# !pip install xlrd
# !pip install openpyxl

# %%
#how to locate python code

# %%
#path working directory(command only for jupyter notebook and not .py files)

# %%
pwd
# Out:
# 'C:\\Users\\Vandana Jha'

# %%
#listing files on my current directory

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 0ADF-0DE7
#
#  Directory of C:\Users\Vandana Jha
#
# 01/31/2022  07:28 PM    <DIR>          .
# 01/31/2022  07:28 PM    <DIR>          ..
# 01/31/2022  07:28 PM    <DIR>          .conda
# 01/05/2022  11:25 PM                25 .condarc
# 01/05/2022  11:24 PM    <DIR>          .continuum
# 01/25/2022  08:12 PM    <DIR>          .ipynb_checkpoints
# 01/06/2022  03:06 PM    <DIR>          .ipython
# 01/06/2022  03:08 PM    <DIR>          .jupyter
# 01/24/2022  01:08 PM    <DIR>          .matplotlib
# 08/20/2021  12:28 PM    <DIR>          .vscode
# 10/03/2020  06:41 PM    <DIR>          3D Objects
# 01/06/2022  02:47 PM    <DIR>          anaconda3
# 08/18/2021  12:01 PM               151 BullseyeCoverageError.txt
# 10/03/2020  06:41 PM    <DIR>          Contacts
# 01/07/2022  04:56 PM    <DIR>          Desktop
# 01/31/2022  03:17 PM    <DIR>          Documents
# 01/31/2022  03:51 PM    <DIR>          Downloads
# ...

# %%
#as tipscsv file is located in the same file path as python code 
df=pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.head()
#it shows some initial rows
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
#can also mention the value of rows to be shown
df.head(20)
# Out:
#     total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0        16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1        10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2        21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3        23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4        24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5        25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6         8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7        26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8        15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9        14.78  3.23    Male     No  Sun  Dinner     2              7.39
# 10       10.27  1.71    Male     No  Sun  Dinner     2              5.14
# 11       35.26  5.00  Female     No  Sun  Dinner     4              8.82
# ...

# %%
#from below
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 239    Michael Avila  5296068606052842    Sat2657
# 240   Monica Sanders  3506806155565404    Sat1766
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
df.tail(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 234    Tracy Douglas  4097938155941930    Sat7220
# ...

# %%
df.info()
#it shows the no of entries ,columns and everything
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %%
#working with cloumns

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
type(df['total_bill'])
# Out:
# pandas.core.series.Series

# %%
mycols=['total_bill','tip']
df[mycols]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
#calling columns directly
df[['total_bill','tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
#adding two columns
df['total_bill']+df['tip']
# Out:
# 0      18.00
# 1      12.00
# 2      24.51
# 3      26.99
# 4      28.20
#        ...
# 239    34.95
# 240    29.18
# 241    24.67
# 242    19.57
# 243    21.78
# Length: 244, dtype: float64

# %%
#operations on columns
df['tip_percentage']=100*df['tip']/df['total_bill']
df['tip_percentage']
# Out:
# 0       5.944673
# 1      16.054159
# 2      16.658734
# 3      13.978041
# 4      14.680765
#          ...
# 239    20.392697
# 240     7.358352
# 241     8.822232
# 242     9.820426
# 243    15.974441
# Name: tip_percentage, Length: 244, dtype: float64

# %%
df['price_per_person']=df['total_bill']/df['size']
df['price_per_person']
#creating new columns
# Out:
# 0       8.495000
# 1       3.446667
# 2       7.003333
# 3      11.840000
# 4       6.147500
#          ...
# 239     9.676667
# 240    13.590000
# 241    11.335000
# 242     8.910000
# 243     9.390000
# Name: price_per_person, Length: 244, dtype: float64

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2          8.495000
# 1       10.34  1.66    Male     No  Sun  Dinner     3          3.446667
# 2       21.01  3.50    Male     No  Sun  Dinner     3          7.003333
# 3       23.68  3.31    Male     No  Sun  Dinner     2         11.840000
# 4       24.59  3.61  Female     No  Sun  Dinner     4          6.147500
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608       16.054159
# 2      Travis Walters  6011812112971322    Sun4458       16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260       13.978041
# 4        Tonya Carter  4832732618637221    Sun2251       14.680765

# %%
df.info()#no. of columns changed
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
#  11  tip_percentage    244 non-null    float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 23.0+ KB

# %%
#rounding of the numbers
df['tip_percentage']=np.round(100*df['tip']/df['total_bill'],2)
df['tip_percentage']
# Out:
# 0       5.94
# 1      16.05
# 2      16.66
# 3      13.98
# 4      14.68
#        ...
# 239    20.39
# 240     7.36
# 241     8.82
# 242     9.82
# 243    15.97
# Name: tip_percentage, Length: 244, dtype: float64

# %%
#dropping or removing a row/column
#axis=0 is a row
#axis=1 is a column,default setting is axis=0,thus specify if want to remove a column
df.drop('tip_percentage',axis=1)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2          8.495000
# 1         10.34  1.66    Male     No   Sun  Dinner     3          3.446667
# 2         21.01  3.50    Male     No   Sun  Dinner     3          7.003333
# 3         23.68  3.31    Male     No   Sun  Dinner     2         11.840000
# 4         24.59  3.61  Female     No   Sun  Dinner     4          6.147500
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3          9.676667
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         13.590000
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         11.335000
# 242       17.82  1.75    Male     No   Sat  Dinner     2          8.910000
# 243       18.78  3.00  Female     No  Thur  Dinner     2          9.390000
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df
#the drop was just temporary and did not affect orfiginal df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2          8.495000
# 1         10.34  1.66    Male     No   Sun  Dinner     3          3.446667
# 2         21.01  3.50    Male     No   Sun  Dinner     3          7.003333
# 3         23.68  3.31    Male     No   Sun  Dinner     2         11.840000
# 4         24.59  3.61  Female     No   Sun  Dinner     4          6.147500
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3          9.676667
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         13.590000
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         11.335000
# 242       17.82  1.75    Male     No   Sat  Dinner     2          8.910000
# 243       18.78  3.00  Female     No  Thur  Dinner     2          9.390000
#
#              Payer Name         CC Number Payment ID  tip_percentage
# ...

# %%
#to make the drop permanent
df=df.drop('tip_percentage',axis=1)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2          8.495000
# 1         10.34  1.66    Male     No   Sun  Dinner     3          3.446667
# 2         21.01  3.50    Male     No   Sun  Dinner     3          7.003333
# 3         23.68  3.31    Male     No   Sun  Dinner     2         11.840000
# 4         24.59  3.61  Female     No   Sun  Dinner     4          6.147500
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3          9.676667
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         13.590000
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         11.335000
# 242       17.82  1.75    Male     No   Sat  Dinner     2          8.910000
# 243       18.78  3.00  Female     No  Thur  Dinner     2          9.390000
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.shape
# Out:
# (244, 11)

# %%
df.shape[1]
#returns no of columns
# Out:
# 11

# %%
#working with the rows

# %%
df.set_index("Payment ID")
#converting columns to index
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959             8.495000  Christy Cunningham  3560325168603410
# ...

# %%
#making a permanent change
df=df.set_index("Payment ID")
df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959             8.495000  Christy Cunningham  3560325168603410
# ...

# %%
#back to columns
df.reset_index()
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number
# 0            8.495000  Christy Cunningham  3560325168603410
# ...

# %%
df=df.set_index("Payment ID")
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\VANDAN~1\AppData\Local\Temp/ipykernel_8712/3184895314.py in <module>
# ----> 1 df=df.set_index("Payment ID")
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: "None of ['Payment ID'] are in the columns"

# %%
#grabing rows using number index or labelled index
df.iloc[0]
#first row
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                 8.495
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
#using labelled index
df.loc['Sun2959']
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                 8.495
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
df.iloc[0:4]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959             8.495000  Christy Cunningham  3560325168603410
# Sun4608             3.446667      Douglas Tucker  4478071379779230
# Sun4458             7.003333      Travis Walters  6011812112971322
# Sun5260            11.840000    Nathaniel Harris  4676137647685994

# %%
df.loc[['Sun2959','Sun5260']]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                8.495  Christy Cunningham  3560325168603410
# Sun5260               11.840    Nathaniel Harris  4676137647685994

# %%
df.drop('Sun2959',axis=0)
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608             3.446667    Douglas Tucker  4478071379779230
# ...

# %%
one_row=df.iloc[0]
one_row
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                 8.495
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
df.append(one_row)

#append to the end
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959             8.495000  Christy Cunningham  3560325168603410
# ...

# %%
#conditional filtering

# %%
# df['total_bill'] > 30
bool_series = df['total_bill'] > 30
df[bool_series]
# Out:
#             total_bill    tip     sex smoker   day    time  size  \
# Payment ID
# Sun6686          35.26   5.00  Female     No   Sun  Dinner     4
# Sat239           39.42   7.58    Male     No   Sat  Dinner     4
# Sat6373          31.27   5.00    Male     No   Sat  Dinner     3
# Sun2274          30.40   5.60    Male     No   Sun  Dinner     4
# Sun9677          32.40   6.00    Male     No   Sun  Dinner     4
# Sun6165          34.81   5.20  Female     No   Sun  Dinner     4
# Sat8903          38.01   3.00    Male    Yes   Sat  Dinner     4
# Sat8139          48.27   6.73    Male     No   Sat  Dinner     4
# Thur8801         32.68   5.00    Male    Yes  Thur   Lunch     2
# Thur7972         34.83   5.17  Female     No  Thur   Lunch     4
# Fri9628          40.17   4.73    Male    Yes   Fri  Dinner     4
# Sat6240          44.30   2.50  Female    Yes   Sat  Dinner     3
# Sun591           38.07   4.00    Male     No   Sun  Dinner     3
# ...

# %%
#directing applying condition
df[df['total_bill']>30]
# Out:
#             total_bill    tip     sex smoker   day    time  size  \
# Payment ID
# Sun6686          35.26   5.00  Female     No   Sun  Dinner     4
# Sat239           39.42   7.58    Male     No   Sat  Dinner     4
# Sat6373          31.27   5.00    Male     No   Sat  Dinner     3
# Sun2274          30.40   5.60    Male     No   Sun  Dinner     4
# Sun9677          32.40   6.00    Male     No   Sun  Dinner     4
# Sun6165          34.81   5.20  Female     No   Sun  Dinner     4
# Sat8903          38.01   3.00    Male    Yes   Sat  Dinner     4
# Sat8139          48.27   6.73    Male     No   Sat  Dinner     4
# Thur8801         32.68   5.00    Male    Yes  Thur   Lunch     2
# Thur7972         34.83   5.17  Female     No  Thur   Lunch     4
# Fri9628          40.17   4.73    Male    Yes   Fri  Dinner     4
# Sat6240          44.30   2.50  Female    Yes   Sat  Dinner     3
# Sun591           38.07   4.00    Male     No   Sun  Dinner     3
# ...

# %%
df[df['sex'] == 'Male']

# %%
#multiple conditions
df[(df['total_bill'] > 30) & (df['sex']=='Male')]
# Out:
#             total_bill    tip   sex smoker   day    time  size  \
# Payment ID
# Sat239           39.42   7.58  Male     No   Sat  Dinner     4
# Sat6373          31.27   5.00  Male     No   Sat  Dinner     3
# Sun2274          30.40   5.60  Male     No   Sun  Dinner     4
# Sun9677          32.40   6.00  Male     No   Sun  Dinner     4
# Sat8903          38.01   3.00  Male    Yes   Sat  Dinner     4
# Sat8139          48.27   6.73  Male     No   Sat  Dinner     4
# Thur8801         32.68   5.00  Male    Yes  Thur   Lunch     2
# Fri9628          40.17   4.73  Male    Yes   Fri  Dinner     4
# Sun591           38.07   4.00  Male     No   Sun  Dinner     3
# Thur1025         34.30   6.70  Male     No  Thur   Lunch     6
# Thur3621         41.19   5.00  Male     No  Thur   Lunch     5
# Sun7518          48.17   5.00  Male     No   Sun  Dinner     6
# Sun3719          31.71   4.50  Male     No   Sun  Dinner     4
# Sat1954          50.81  10.00  Male    Yes   Sat  Dinner     3
# ...

# %%
df[(df['total_bill'] > 30) & ~(df['sex']=='Male')]
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun6686          35.26  5.00  Female     No   Sun  Dinner     4
# Sun6165          34.81  5.20  Female     No   Sun  Dinner     4
# Thur7972         34.83  5.17  Female     No  Thur   Lunch     4
# Sat6240          44.30  2.50  Female    Yes   Sat  Dinner     3
# Thur9313         43.11  5.00  Female    Yes  Thur   Lunch     4
# Sat8863          30.14  3.09  Female    Yes   Sat  Dinner     4
# Sat9777          35.83  4.67  Female     No   Sat  Dinner     3
#
#             price_per_person      Payer Name         CC Number
# Payment ID
# Sun6686             8.815000    Diane Macias  4577817359320969
# Sun6165             8.702500    Emily Daniel  4291280793094374
# Thur7972            8.707500     Shawna Cook  6011787464177340
# Sat6240            14.766667   Heather Cohen   379771118886604
# Thur9313           10.777500     Brooke Soto  5544902205760175
# ...

# %%
df[(df['day'] =='Sun') | (df['day']=='Sat')]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# ...                ...   ...     ...    ...  ...     ...   ...
# Sat9777          35.83  4.67  Female     No  Sat  Dinner     3
# Sat2657          29.03  5.92    Male     No  Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes  Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes  Sat  Dinner     2
# Sat17            17.82  1.75    Male     No  Sat  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959             8.495000  Christy Cunningham  3560325168603410
# ...

# %%
#conditional operator isin()
options = ['Sat','Sun']
df['day'].isin(options)
# Out:
# Payment ID
# Sun2959     True
# Sun4608     True
# Sun4458     True
# Sun5260     True
# Sun2251     True
#            ...
# Sat2657     True
# Sat1766     True
# Sat3880     True
# Sat17       True
# Thur672    False
# Name: day, Length: 244, dtype: bool

# %%
#direct application
df[df['day'].isin(['Sat','Sun'])]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# ...                ...   ...     ...    ...  ...     ...   ...
# Sat9777          35.83  4.67  Female     No  Sat  Dinner     3
# Sat2657          29.03  5.92    Male     No  Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes  Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes  Sat  Dinner     2
# Sat17            17.82  1.75    Male     No  Sat  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959             8.495000  Christy Cunningham  3560325168603410
# ...

# %%
#useful mehtods(inbuilt mehtods)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 244 entries, Sun2959 to Thur672
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 29.1+ KB

# %%
#apply method
def last_four(num):
    return str(num)[-4:]
df['CC Number'][0]
# Out:
# 3560325168603410

# %%
df['last_four'] = df['CC Number'].apply(last_four)
df['last_four']
# Out:
# Payment ID
# Sun2959    3410
# Sun4608    9230
# Sun4458    1322
# Sun5260    5994
# Sun2251    7221
#            ...
# Sat2657    2842
# Sat1766    5404
# Sat3880    7196
# Sat17      0950
# Thur672    8139
# Name: last_four, Length: 244, dtype: object

# %%
#apply with LAMBDA
def simple(num):
    return num*2
#converting to lambda
lambda num:num*2
# Out:
# <function __main__.<lambda>(num)>

# %%
df['total_bill'].apply(lambda bill:bill*0.18)
# Out:
# Payment ID
# Sun2959    3.0582
# Sun4608    1.8612
# Sun4458    3.7818
# Sun5260    4.2624
# Sun2251    4.4262
#             ...
# Sat2657    5.2254
# Sat1766    4.8924
# Sat3880    4.0806
# Sat17      3.2076
# Thur672    3.3804
# Name: total_bill, Length: 244, dtype: float64

# %%
#applying to multiple columns
def quality(total_bill,tip):
    if tip/total_bill  > 0.25:
        return "Generous"
    else:
        return "Other"
df[['total_bill','tip']].apply(lambda df:quality(df['total_bill']['tip']),axis=1)

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000         244.00000  2.440000e+02
# mean    19.785943    2.998279    2.569672           7.88823  2.563496e+15
# std      8.902412    1.383638    0.951100           2.91435  2.369340e+15
# min      3.070000    1.000000    1.000000           2.87500  6.040679e+10
# 25%     13.347500    2.000000    2.000000           5.80250  3.040731e+13
# 50%     17.795000    2.900000    2.000000           7.25500  3.525318e+15
# 75%     24.127500    3.562500    3.000000           9.39000  4.553675e+15
# max     50.810000   10.000000    6.000000          20.27500  6.596454e+15

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888230e+00  2.914350e+00  2.875000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.802500e+00  7.255000e+00  9.390000e+00  2.027500e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %%
df.sort_values('tip')
# Out:
#             total_bill    tip     sex smoker   day    time  size  \
# Payment ID
# Sat3455           3.07   1.00  Female    Yes   Sat  Dinner     1
# Sat5032          12.60   1.00    Male    Yes   Sat  Dinner     2
# Fri3780           5.75   1.00  Female    Yes   Fri  Dinner     2
# Sat4801           7.25   1.00  Female     No   Sat  Dinner     1
# Sun2959          16.99   1.01  Female     No   Sun  Dinner     2
# ...                ...    ...     ...    ...   ...     ...   ...
# Thur1025         34.30   6.70    Male     No  Thur   Lunch     6
# Sat8139          48.27   6.73    Male     No   Sat  Dinner     4
# Sat239           39.42   7.58    Male     No   Sat  Dinner     4
# Sat4590          48.33   9.00    Male     No   Sat  Dinner     4
# Sat1954          50.81  10.00    Male    Yes   Sat  Dinner     3
#
#             price_per_person          Payer Name         CC Number last_four
# Payment ID
# Sat3455             3.070000       Tiffany Brock  4359488526995267      5267
# ...

# %%
df.sort_values(['tip','size'])
#sort based on the values of size
# Out:
#             total_bill    tip     sex smoker   day    time  size  \
# Payment ID
# Sat3455           3.07   1.00  Female    Yes   Sat  Dinner     1
# Sat4801           7.25   1.00  Female     No   Sat  Dinner     1
# Fri3780           5.75   1.00  Female    Yes   Fri  Dinner     2
# Sat5032          12.60   1.00    Male    Yes   Sat  Dinner     2
# Sun2959          16.99   1.01  Female     No   Sun  Dinner     2
# ...                ...    ...     ...    ...   ...     ...   ...
# Thur1025         34.30   6.70    Male     No  Thur   Lunch     6
# Sat8139          48.27   6.73    Male     No   Sat  Dinner     4
# Sat239           39.42   7.58    Male     No   Sat  Dinner     4
# Sat4590          48.33   9.00    Male     No   Sat  Dinner     4
# Sat1954          50.81  10.00    Male    Yes   Sat  Dinner     3
#
#             price_per_person          Payer Name         CC Number last_four
# Payment ID
# Sat3455             3.070000       Tiffany Brock  4359488526995267      5267
# ...

# %%
#correlation checks
df.corr()
# Out:
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.675734  0.598315          0.647497   0.104576
# tip                 0.675734  1.000000  0.489299          0.347393   0.110857
# size                0.598315  0.489299  1.000000         -0.175412  -0.030239
# price_per_person    0.647497  0.347393 -0.175412          1.000000   0.135271
# CC Number           0.104576  0.110857 -0.030239          0.135271   1.000000

# %%
df[['total_bill','tip']].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
df['total_bill'].max()
# Out:
# 50.81

# %%
df['total_bill'].idxmax()
# Out:
# 'Sat1954'

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
#replace
df['Tip Quality'].replace(to_replace='Other',value='Ok')
